# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import visualization as vis

# %% [markdown]
# ## Test Histograms

# %%
data = [np.random.randn(20000)+1, np.random.randn(20000)*0.05, np.random.randn(20000)*0.01, np.random.randn(20000)*0.05 + 0.3]
classes = ['fancy method: a','fancy method: b', 'another method: c','finally: d']

# %%
vis.histogram(data,classes)

# %% [markdown]
# ## Test ROC Curves

# %%
samples = np.random.randn(20000)
data = [(samples+2, samples), (samples, samples*0.7 + 0.3), (samples, samples*0.2 + 0.3)]
names = ['a', 'b', 'c']

# %%
roc_plot = vis.roc(data,names)

# %% [markdown]
# ## Test Inidivual Samples Plot

# %%
real = np.random.randn(20)
adv = real + np.random.randn(20)*2
noise = real + np.random.randn(20)*1
data = [real,adv]#,noise]
names = ['x_real', 'x_adv']# 'x_noise']

# %%
vis.individual(data,names) # without noise

# %%
real = np.random.randn(20)
adv = real + np.random.randn(20)*2
noise = real + np.random.randn(20)*1
data = [real,adv,noise]
names = ['x_real', 'x_adv', 'x_noise']

# %%
vis.individual(data,names) # with noise

# %% [markdown]
# ## Test Attack and Image Visualization

# %%
adv_ims = [np.clip(np.random.randn(32,32,3)+0.5,0,1) for _ in range(10)]
real_ims = [np.clip(np.random.randn(32,32,3)+0.5,0,1) for _ in range(10)]
titles = ['scary adversarial images', 'normal images']
vis.images(adv_ims,real_ims,titles)
